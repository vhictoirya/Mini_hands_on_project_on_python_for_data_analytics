# %% [markdown]
# ### Load Joblib

# %%
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the DataFrame from the database folder
save_path = r'C:\Users\FFFO CASHIER PT\OneDrive\Desktop\Hands-on Projects\database\df_prices.joblib'
df_prices_loaded = joblib.load(save_path)

print(df_prices_loaded.head())
# Out:
#                            bitcoin     ethereum      solana    ripple
# timestamp
# 2025-07-06 12:00:00  108079.788276  2514.979427  147.860826  2.264318
# 2025-07-06 13:00:00  108226.778238  2520.355851  148.786268  2.273416
# 2025-07-06 14:00:00  108852.242818  2560.016103  151.526358  2.284491
# 2025-07-06 15:00:00  108881.002859  2558.079219  151.513413  2.270192
# 2025-07-06 16:00:00  108842.004636  2555.859603  151.277611  2.275761

# %% [markdown]
# ### Token Correlation Heatmap

# %%
# Calculate the correlation matrix
corr = df_prices_loaded.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Token Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Token Volatility

# %%
# Compute volatility (standard deviation of returns) for each token

# Calculate log returns
returns = df_prices_loaded.pct_change().apply(lambda x: np.log1p(x))

# Compute volatility (standard deviation of log returns)
volatility = returns.std()

print("Volatility for each token:")
print(volatility)
# Out:
# Volatility for each token:
# bitcoin     0.003190
# ethereum    0.006457
# solana      0.006883
# ripple      0.008496
# dtype: float64

# %% [markdown]
# ### Correlation of Tokens Return

# %%
print(returns.head())
# Out:
#                       bitcoin  ethereum    solana    ripple
# timestamp
# 2025-07-06 12:00:00       NaN       NaN       NaN       NaN
# 2025-07-06 13:00:00  0.001359  0.002135  0.006239  0.004010
# 2025-07-06 14:00:00  0.005763  0.015613  0.018249  0.004860
# 2025-07-06 15:00:00  0.000264 -0.000757 -0.000085 -0.006279
# 2025-07-06 16:00:00 -0.000358 -0.000868 -0.001558  0.002450

# %%
# Calculate the correlation matrix
corr = returns.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Token Correlation Heatmap")
plt.show()
